# %% [markdown]
# # Laboratorio 3.1 - Tarea 2: introducción a Python y JupyterLab
#
# **Estudiante:** Santiago Perez Garzon
#
# Se ejecutó la guía PythonCheatSheet de AWS Academy para practicar celdas Markdown, tipos de datos, estructuras de control, funciones y operaciones básicas con pandas.

# %% [markdown]
# ## Tipos y estructuras de datos

# %%
entero = 12
decimal = 3.5
texto = 'EDA en SageMaker'
valores = [entero, decimal, texto]
[(valor, type(valor).__name__) for valor in valores]

# %% [markdown]
# ## Control de flujo y funciones

# %%
def clasificar(valor):
    return 'alto' if valor >= 10 else 'bajo'

print([clasificar(valor) for valor in [4, 10, 15]])
# Out:
# ['bajo', 'alto', 'alto']

# %% [markdown]
# ## Ejemplo tabular

# %%
import pandas as pd
df_ejemplo = pd.DataFrame({'variable': ['A', 'B', 'C'], 'valor': [12, 18, 9]})
df_ejemplo.describe(include='all')

# %% [markdown]
# ## Resultado
# Las celdas combinan explicación, código y salida. La práctica verificó el kernel y preparó el entorno para importar datos.
