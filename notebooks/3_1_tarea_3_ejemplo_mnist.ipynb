# %% [markdown]
# # Laboratorio 3.1 - Tarea 3: inspección del ejemplo MNIST
#
# **Estudiante:** Santiago Perez Garzon
#
# Se abrió e inspeccionó `linear_learner_mnist.ipynb`. El ejemplo muestra la preparación de MNIST, entrenamiento con Linear Learner, despliegue y validación. Siguiendo la guía, no se ejecutó porque requiere recursos y rutas de S3.

# %% [markdown]
# ## Flujo identificado

# %%
# Código representativo inspeccionado; no se ejecuta en esta tarea.
# 1. Cargar y transformar MNIST
# 2. Subir datos a Amazon S3
# 3. Configurar Linear Learner
# 4. Entrenar, desplegar y evaluar

# %% [markdown]
# ## Propósito
# La inspección permitió reconocer una canalización completa de aprendizaje automático sin crear recursos adicionales.
